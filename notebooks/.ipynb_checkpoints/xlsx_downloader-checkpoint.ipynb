# %%
import os
import time
import json
import requests
from openpyxl import load_workbook
import pandas as pd

# %%
# http request authentication
header = {'Authorization': 'token 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'}

base_url = 'https://api.github.com/search/code?q=extension:xlsx'
page_url = '&per_page=100'

def search_xlsx_on_github(min_file_size, max_file_size, download_path, debug=False):
    search_url = base_url + '+size:>' + str(min_file_size) + '+size:<' + str(max_file_size) + page_url
    print(search_url)
    
    # query GitHub
    req = get_github_request(search_url, header)
    json = req.json()
    head = req.headers
    if debug:
        print('response: \n', req)
        print('headers: \n', head)
        print('JSON: \n', json)
        #print('response content: \n', r.content)
        print()
        print()
    
    download_xlsx(download_path, json, debug)
    
    while 'next' in req.links:
        next_url = req.links['next']['url']
        req = get_github_request(next_url, header)
        json = req.json()
        head = req.headers
        
        download_xlsx(download_path, json, debug)
        
        
def get_github_request(url, header):
    r = requests.get(url, headers=header)
    if r.status_code == 403:
        wait = 0
        try:
            wait = r.headers['Retry-After']
        except KeyError:
            wait = 30
        print("%s: Hit rate limit. Retry after %s seconds" % (r.headers['Date'], wait))
        time.sleep(int(wait) + 1)
        return get_github_request(url, header)
    return r

def download_xlsx(download_path, json, debug):
    if debug:
        print(json)
    for item in json['items']:
        file_url = item['html_url']
        filename = item['name']
        req = get_github_request(file_url + '?raw=true', header)
        if not os.path.exists(download_path):
            os.makedirs(download_path)
        open(download_path + filename, 'wb').write(req.content)
        num_cells, num_formulae = check_xlsx_for_formulae(download_path + filename)
        print('downloaded ' + filename + 'with formula percent', num_formulae / num_cells)
        if num_cells == 0 or num_formulae / num_cells < .3:
            print('deleting ' + filename + ' for having formula percent', num_formulae / num_cells)
            os.remove(download_path + filename)
        

def check_xlsx_for_formulae(file_path):
    num_cells = 0
    num_formulae = 0
    try:
        wb = load_workbook(filename = file_path)
    except:
        return (0,0)
    sheet_names = wb.sheetnames
    for sheet in sheet_names:
        ws = wb[sheet]
        for row in ws.iter_rows():
            for cell in row:
                if cell.value is not None:
                    num_cells += 1
                if type(cell.value) is str:
                    if len(cell.value) > 0 and cell.value[0] == '=':
                        num_formulae += 1
    return (num_cells, num_formulae)

# %%
# do first search
download_path = "./xlsxDownloads/100000kb+/"
search_xlsx_on_github(100000000, 100000000000, download_path, debug=False)
# Out:
# https://api.github.com/search/code?q=extension:xlsx+size:>100000000+size:<100000000000&per_page=100
# downloaded Tests.xlsxwith formula percent 0.0
# deleting Tests.xlsx for having formula percent 0.0
# downloaded Config.xlsxwith formula percent 0.0
# deleting Config.xlsx for having formula percent 0.0
# downloaded Exercicio_config_PCs.xlsxwith formula percent 0.034722222222222224
# deleting Exercicio_config_PCs.xlsx for having formula percent 0.034722222222222224
# downloaded Resposta Parte 1 - Cotacao de Seguros.xlsxwith formula percent 0.0
# deleting Resposta Parte 1 - Cotacao de Seguros.xlsx for having formula percent 0.0
# downloaded Resposta Parte 2  - Restaurante.xlsxwith formula percent 0.0
# deleting Resposta Parte 2  - Restaurante.xlsx for having formula percent 0.0
# downloaded typical-tables.xlsxwith formula percent 0.0
# deleting typical-tables.xlsx for having formula percent 0.0
# downloaded test-side-by-side-tables.xlsxwith formula percent 0.0
# deleting test-side-by-side-tables.xlsx for having formula percent 0.0
# downloaded Notas control reposición 1.xlsxwith formula percent 0.0
# deleting Notas control reposición 1.xlsx for having formula percent 0.0
# downloaded Evaluación (Respuestas).xlsxwith formula percent 0.37381309345327335
# downloaded Excel Alumnos Betas.xlsxwith formula percent 0.0
# deleting Excel Alumnos Betas.xlsx for having formula percent 0.0
# downloaded source.xlsxwith formula percent 0.004648969141625118
# deleting source.xlsx for having formula percent 0.004648969141625118
# downloaded Tbills.xlsxwith formula percent 0.0
# deleting Tbills.xlsx for having formula percent 0.0
# downloaded Excel Alumnos Betas.xlsxwith formula percent 0.0
# deleting Excel Alumnos Betas.xlsx for having formula percent 0.0
# downloaded Evaluación (Respuestas).xlsxwith formula percent 0.012716763005780347
# deleting Evaluación (Respuestas).xlsx for having formula percent 0.012716763005780347
# downloaded Excel Alumnos Portafolio.xlsxwith formula percent 0.025236593059936908
# deleting Excel Alumnos Portafolio.xlsx for having formula percent 0.025236593059936908
# downloaded Notas del parcial.xlsxwith formula percent 0.0
# deleting Notas del parcial.xlsx for having formula percent 0.0
# downloaded Ayudantía semana 8.xlsxwith formula percent 0.435066111211737
# downloaded State Codes.xlsxwith formula percent 0.0
# deleting State Codes.xlsx for having formula percent 0.0
# downloaded plot.xlsxwith formula percent 0.0
# deleting plot.xlsx for having formula percent 0.0
# downloaded study-steps-data.xlsxwith formula percent 0.09568290835647564
# deleting study-steps-data.xlsx for having formula percent 0.09568290835647564
# Wed, 15 Dec 2021 08:00:45 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:01:16 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:01:51 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:02:22 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:02:56 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:03:27 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:04:03 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:04:34 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:05:08 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:05:39 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:06:14 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:06:45 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:07:20 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:07:51 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:08:26 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:08:57 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:09:33 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:10:04 GMT: Hit rate limit. Retry after 30 seconds

# %%
download_path = "./xlsxDownloads/10000-100000kb/"
search_xlsx_on_github(10000, 99999, download_path, debug=False)
# Out:
# https://api.github.com/search/code?q=extension:xlsx+size:>10000+size:<99999&per_page=100
# Wed, 15 Dec 2021 08:22:44 GMT: Hit rate limit. Retry after 30 seconds
# downloaded sila-poprawy.xlsxwith formula percent 0.37272727272727274
# downloaded AEMLION-R3-BOM.xlsxwith formula percent 0.0
# deleting AEMLION-R3-BOM.xlsx for having formula percent 0.0
# downloaded AEMLION-R2.02-BOM.xlsxwith formula percent 0.0
# deleting AEMLION-R2.02-BOM.xlsx for having formula percent 0.0
# downloaded AEMLION-R2-BOM.xlsxwith formula percent 0.0
# deleting AEMLION-R2-BOM.xlsx for having formula percent 0.0
# downloaded productionPlan_form_ver1.xlsxwith formula percent 0.0
# deleting productionPlan_form_ver1.xlsx for having formula percent 0.0
# downloaded ExportFGsForm.xlsxwith formula percent 0.20408163265306123
# deleting ExportFGsForm.xlsx for having formula percent 0.20408163265306123
# downloaded ExportFGsForm.xlsxwith formula percent 0.20408163265306123
# deleting ExportFGsForm.xlsx for having formula percent 0.20408163265306123
# downloaded MQC-PQC_Template.xlsxwith formula percent 0.0
# deleting MQC-PQC_Template.xlsx for having formula percent 0.0
# downloaded MQC-PQC_Template.xlsxwith formula percent 0.0
# deleting MQC-PQC_Template.xlsx for having formula percent 0.0
# downloaded MQC_Daily.xlsxwith formula percent 0.7360594795539034
# downloaded MQC_Daily.xlsxwith formula percent 0.7360594795539034
# downloaded Form5Common2.xlsxwith formula percent 0.0958904109589041
# deleting Form5Common2.xlsx for having formula percent 0.0958904109589041
# downloaded Form5Common2.xlsxwith formula percent 0.0958904109589041
# deleting Form5Common2.xlsx for having formula percent 0.0958904109589041
# downloaded MQC_Daily.xlsxwith formula percent 0.7360594795539034
# downloaded MQC_Daily.xlsxwith formula percent 0.7360594795539034
# downloaded MQC_Daily.xlsxwith formula percent 0.7360594795539034
# downloaded MQC_Daily.xlsxwith formula percent 0.7360594795539034
# downloaded MQC-PQC_Template.xlsxwith formula percent 0.0
# deleting MQC-PQC_Template.xlsx for having formula percent 0.0
# downloaded MQC-PQC_Template.xlsxwith formula percent 0.0
# deleting MQC-PQC_Template.xlsx for having formula percent 0.0
# downloaded MQC-PQC_Template.xlsxwith formula percent 0.0
# deleting MQC-PQC_Template.xlsx for having formula percent 0.0
# downloaded MQC-PQC_Template.xlsxwith formula percent 0.0
# deleting MQC-PQC_Template.xlsx for having formula percent 0.0
# downloaded MQC-PQC_Template.xlsxwith formula percent 0.0
# deleting MQC-PQC_Template.xlsx for having formula percent 0.0
# downloaded MQC-PQC_Template.xlsxwith formula percent 0.0
# deleting MQC-PQC_Template.xlsx for having formula percent 0.0
# downloaded MQC-PQC_Template.xlsxwith formula percent 0.0
# deleting MQC-PQC_Template.xlsx for having formula percent 0.0
# downloaded MQC-PQC_Template.xlsxwith formula percent 0.0
# deleting MQC-PQC_Template.xlsx for having formula percent 0.0
# downloaded Reliability.xlsxwith formula percent 0.0
# deleting Reliability.xlsx for having formula percent 0.0
# downloaded Reliability.xlsxwith formula percent 0.0
# deleting Reliability.xlsx for having formula percent 0.0
# downloaded Reliability.xlsxwith formula percent 0.0
# deleting Reliability.xlsx for having formula percent 0.0
# downloaded Reliability.xlsxwith formula percent 0.0
# deleting Reliability.xlsx for having formula percent 0.0
# downloaded Reliability.xlsxwith formula percent 0.0
# deleting Reliability.xlsx for having formula percent 0.0
# downloaded Template_MQC.xlsxwith formula percent 0.0
# deleting Template_MQC.xlsx for having formula percent 0.0
# downloaded Template_MQC.xlsxwith formula percent 0.0
# deleting Template_MQC.xlsx for having formula percent 0.0
# downloaded Template_MQC.xlsxwith formula percent 0.0
# deleting Template_MQC.xlsx for having formula percent 0.0
# downloaded Template_MQC.xlsxwith formula percent 0.0
# deleting Template_MQC.xlsx for having formula percent 0.0
# downloaded Reliability.xlsxwith formula percent 0.0
# deleting Reliability.xlsx for having formula percent 0.0
# downloaded Reliability.xlsxwith formula percent 0.0
# deleting Reliability.xlsx for having formula percent 0.0
# downloaded MQC_Daily.xlsxwith formula percent 0.7346938775510204
# downloaded MQC_Daily.xlsxwith formula percent 0.7346938775510204
# downloaded productionPlan_TiengViet.xlsxwith formula percent 0.0
# deleting productionPlan_TiengViet.xlsx for having formula percent 0.0
# downloaded productionPlan_TiengViet.xlsxwith formula percent 0.0
# deleting productionPlan_TiengViet.xlsx for having formula percent 0.0
# downloaded Reliability.xlsxwith formula percent 0.0
# deleting Reliability.xlsx for having formula percent 0.0
# downloaded Reliability.xlsxwith formula percent 0.0
# deleting Reliability.xlsx for having formula percent 0.0
# downloaded BackLogForm3.xlsxwith formula percent 0.9990821029607062
# downloaded BackLogForm3.xlsxwith formula percent 0.9990821029607062
# downloaded BackLogOverview.xlsxwith formula percent 0.9627450980392157
# downloaded BackLogOverview.xlsxwith formula percent 0.9627450980392157
# downloaded Reliability.xlsxwith formula percent 0.0
# deleting Reliability.xlsx for having formula percent 0.0
# downloaded AbsenceForm_v1.xlsxwith formula percent 0.0
# deleting AbsenceForm_v1.xlsx for having formula percent 0.0
# downloaded AbsenceForm_v1.xlsxwith formula percent 0.0
# deleting AbsenceForm_v1.xlsx for having formula percent 0.0
# downloaded AbsenceForm_v1.xlsxwith formula percent 0.0
# deleting AbsenceForm_v1.xlsx for having formula percent 0.0
# downloaded AbsenceForm_v1.xlsxwith formula percent 0.0
# deleting AbsenceForm_v1.xlsx for having formula percent 0.0
# downloaded FORM_MQC_DAILY.xlsxwith formula percent 0.9194915254237288
# downloaded FORM_MQC_DAILY.xlsxwith formula percent 0.9194915254237288
# downloaded Form5Common.xlsxwith formula percent 0.0
# deleting Form5Common.xlsx for having formula percent 0.0
# downloaded Form5Common.xlsxwith formula percent 0.0
# deleting Form5Common.xlsx for having formula percent 0.0
# downloaded Reliability.xlsxwith formula percent 0.0
# deleting Reliability.xlsx for having formula percent 0.0
# downloaded FormTDP.xlsxwith formula percent 0.6273006134969326
# downloaded FormTDP.xlsxwith formula percent 0.6273006134969326
# downloaded BackLogForm3.xlsxwith formula percent 0.9990694789081885
# downloaded BackLogForm3.xlsxwith formula percent 0.9990694789081885
# downloaded BackLogForm3.xlsxwith formula percent 0.9990694789081885
# downloaded BackLogForm3.xlsxwith formula percent 0.9990694789081885
# downloaded BackLogForm3.xlsxwith formula percent 0.9990694789081885
# downloaded BackLogForm3.xlsxwith formula percent 0.9990694789081885
# downloaded BackLogForm3.xlsxwith formula percent 0.9990694789081885
# downloaded BackLogForm3.xlsxwith formula percent 0.9990694789081885
# downloaded BackLogForm3.xlsxwith formula percent 0.9990694789081885
# downloaded productionPlan_form_ver1.xlsxwith formula percent 0.0
# deleting productionPlan_form_ver1.xlsx for having formula percent 0.0
# downloaded productionPlan_form_ver1.xlsxwith formula percent 0.0
# deleting productionPlan_form_ver1.xlsx for having formula percent 0.0
# downloaded productionPlan_form_ver1.xlsxwith formula percent 0.0
# deleting productionPlan_form_ver1.xlsx for having formula percent 0.0
# downloaded ProductionPLan_HouseHold_Form.xlsxwith formula percent 0.0
# deleting ProductionPLan_HouseHold_Form.xlsx for having formula percent 0.0
# downloaded ProductionPLan_HouseHold_Form.xlsxwith formula percent 0.0
# deleting ProductionPLan_HouseHold_Form.xlsx for having formula percent 0.0
# downloaded BackLogForm2.xlsxwith formula percent 0.9990552772651375
# downloaded BackLogForm2.xlsxwith formula percent 0.9990552772651375
# downloaded BackLogForm2.xlsxwith formula percent 0.9990552772651375
# downloaded BackLogForm2.xlsxwith formula percent 0.9990552772651375
# downloaded BackLogForm2.xlsxwith formula percent 0.9990552772651375
# downloaded BackLogForm2.xlsxwith formula percent 0.9990552772651375
# downloaded BackLogForm2.xlsxwith formula percent 0.9990552772651375
# downloaded BackLogForm2.xlsxwith formula percent 0.9990552772651375
# downloaded BackLogForm2.xlsxwith formula percent 0.9990552772651375
# downloaded AttendanceDaily.xlsxwith formula percent 0.9006622516556292
# downloaded AttendanceDaily.xlsxwith formula percent 0.9006622516556292
# downloaded AttendanceDaily.xlsxwith formula percent 0.9006622516556292
# downloaded AttendanceDaily.xlsxwith formula percent 0.9006622516556292
# downloaded MQC_Daily.xlsxwith formula percent 0.7360594795539034
# downloaded MQC_Daily.xlsxwith formula percent 0.7360594795539034
# downloaded MQC_Daily.xlsxwith formula percent 0.7360594795539034
# downloaded MQC-PQC_Template.xlsxwith formula percent 0.0
# deleting MQC-PQC_Template.xlsx for having formula percent 0.0
# downloaded MQC-PQC_Template.xlsxwith formula percent 0.0
# deleting MQC-PQC_Template.xlsx for having formula percent 0.0
# downloaded MQC-PQC_Template.xlsxwith formula percent 0.0
# deleting MQC-PQC_Template.xlsx for having formula percent 0.0
# downloaded FORM_MQC_DAILY.xlsxwith formula percent 0.9194915254237288
# downloaded FORM_MQC_DAILY.xlsxwith formula percent 0.9194915254237288
# downloaded 32readwriteLineStackedChart1.xlsxwith formula percent 0.7058823529411765
# downloaded 32complexChartreadwrite.xlsxwith formula percent 0.7058823529411765
# C:\Users\jonat\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Sparkline Group extension is not supported and will be removed
#   warn(msg)
# downloaded 32readwriteDonutChartExploded1.xlsxwith formula percent 0.5026178010471204
# downloaded 32readwritePieChartExploded3D1.xlsxwith formula percent 0.5026178010471204
# downloaded 32readwriteColumnChart1.xlsxwith formula percent 0.7058823529411765
# downloaded 32readwriteAreaStackedChart2.xlsxwith formula percent 0.7058823529411765
# downloaded 32readwriteLinePercentageChart1.xlsxwith formula percent 0.7058823529411765
# Wed, 15 Dec 2021 08:26:41 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:27:12 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:27:47 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:28:18 GMT: Hit rate limit. Retry after 30 seconds
# downloaded search_2020-2021_All DBs Merged.xlsxwith formula percent 0.0
# deleting search_2020-2021_All DBs Merged.xlsx for having formula percent 0.0
# downloaded ScienceDirect.xlsxwith formula percent 0.0
# deleting ScienceDirect.xlsx for having formula percent 0.0
# downloaded ACM.xlsxwith formula percent 0.0
# deleting ACM.xlsx for having formula percent 0.0
# downloaded Papers_All.xlsxwith formula percent 0.0
# deleting Papers_All.xlsx for having formula percent 0.0
# downloaded Springer.xlsxwith formula percent 0.0
# deleting Springer.xlsx for having formula percent 0.0
# downloaded scopus.xlsxwith formula percent 0.0
# deleting scopus.xlsx for having formula percent 0.0
# downloaded IEEE.xlsxwith formula percent 0.0
# deleting IEEE.xlsx for having formula percent 0.0
# downloaded Appendix D.xlsxwith formula percent 0.0
# deleting Appendix D.xlsx for having formula percent 0.0
# downloaded Papers filtering results_2008-2020.xlsxwith formula percent 0.0
# deleting Papers filtering results_2008-2020.xlsx for having formula percent 0.0
# downloaded Appendix B.xlsxwith formula percent 0.0
# deleting Appendix B.xlsx for having formula percent 0.0
# downloaded Papers filtering results_2020-2021.xlsxwith formula percent 0.0
# deleting Papers filtering results_2020-2021.xlsx for having formula percent 0.0
# downloaded Appendix A.xlsxwith formula percent 0.0
# deleting Appendix A.xlsx for having formula percent 0.0
# downloaded veryStaticEnv12-2.xlsxwith formula percent 0.23715415019762845
# deleting veryStaticEnv12-2.xlsx for having formula percent 0.23715415019762845
# Wed, 15 Dec 2021 08:29:03 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:29:34 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:30:08 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:30:39 GMT: Hit rate limit. Retry after 30 seconds
# downloaded Jordbruksverket Totalkonsumtion JO1301K2_20210921-140628.xlsxwith formula percent 0.0
# deleting Jordbruksverket Totalkonsumtion JO1301K2_20210921-140628.xlsx for having formula percent 0.0
# downloaded vgsales.xlsxwith formula percent 0.0
# deleting vgsales.xlsx for having formula percent 0.0
# downloaded datos_edadesposos.xlsxwith formula percent 0.0
# deleting datos_edadesposos.xlsx for having formula percent 0.0
# downloaded raw_fighter_details.xlsxwith formula percent 0.0
# deleting raw_fighter_details.xlsx for having formula percent 0.0
# downloaded ALL UFC FIGHTERS 2_23_2016 SHERDOG.COM.xlsxwith formula percent 0.0
# deleting ALL UFC FIGHTERS 2_23_2016 SHERDOG.COM.xlsx for having formula percent 0.0
# downloaded ALL UFC FIGHTS 2_23_2016 SHERDOG.COM.xlsxwith formula percent 0.0
# deleting ALL UFC FIGHTS 2_23_2016 SHERDOG.COM.xlsx for having formula percent 0.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-b92938c634aa> in <module>
#       1 download_path = "./xlsxDownloads/10000-100000kb/"
# ----> 2 search_xlsx_on_github(10000, 99999, download_path, debug=False)
#
# <ipython-input-46-c05139230cd6> in search_xlsx_on_github(min_file_size, max_file_size, download_path, debug)
#      29         head = req.headers
#      30
# ---> 31         download_xlsx(download_path, json, debug)
#      32
#      33
#
# <ipython-input-46-c05139230cd6> in download_xlsx(download_path, json, debug)
#      55             os.makedirs(download_path)
#      56         open(download_path + filename, 'wb').write(req.content)
# ---> 57         num_cells, num_formulae = check_xlsx_for_formulae(download_path + filename)
#      58         print('downloaded ' + filename + 'with formula percent', num_formulae / num_cells)
#      59         if num_cells == 0 or num_formulae / num_cells < .3:
#
# <ipython-input-46-c05139230cd6> in check_xlsx_for_formulae(file_path)
#      65     num_cells = 0
#      66     num_formulae = 0
# ---> 67     wb = load_workbook(filename = file_path)
#      68     sheet_names = wb.sheetnames
#      69     for sheet in sheet_names:
#
# ~\anaconda3\lib\site-packages\openpyxl\reader\excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     315     reader = ExcelReader(filename, read_only, keep_vba,
#     316                         data_only, keep_links)
# --> 317     reader.read()
#     318     return reader.wb
#
# ~\anaconda3\lib\site-packages\openpyxl\reader\excel.py in read(self)
#     279         self.read_properties()
#     280         self.read_theme()
# --> 281         apply_stylesheet(self.archive, self.wb)
#     282         self.read_worksheets()
#     283         self.parser.assign_names()
#
# ~\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py in apply_stylesheet(archive, wb)
#     196
#     197     node = fromstring(src)
# --> 198     stylesheet = Stylesheet.from_tree(node)
#     199
#     200     wb._borders = IndexedList(stylesheet.borders)
#
# ~\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py in from_tree(cls, node)
#     101         for k in attrs:
#     102             del node.attrib[k]
# --> 103         return super(Stylesheet, cls).from_tree(node)
#     104
#     105
#
# ~\anaconda3\lib\site-packages\openpyxl\descriptors\serialisable.py in from_tree(cls, node)
#      81             if hasattr(desc, 'from_tree'):
#      82                 #descriptor manages conversion
# ---> 83                 obj = desc.from_tree(el)
#      84             else:
#      85                 if hasattr(desc.expected_type, "from_tree"):
#
# ~\anaconda3\lib\site-packages\openpyxl\descriptors\sequence.py in from_tree(self, node)
#      83
#      84     def from_tree(self, node):
# ---> 85         return [self.expected_type.from_tree(el) for el in node]
#      86
#      87
#
# ~\anaconda3\lib\site-packages\openpyxl\descriptors\sequence.py in <listcomp>(.0)
#      83
#      84     def from_tree(self, node):
# ---> 85         return [self.expected_type.from_tree(el) for el in node]
#      86
#      87
#
# ~\anaconda3\lib\site-packages\openpyxl\styles\fills.py in from_tree(cls, el)
#      62         child = children[0]
#      63         if "patternFill" in child.tag:
# ---> 64             return PatternFill._from_tree(child)
#      65         return super(Fill, GradientFill).from_tree(child)
#      66
#
# ~\anaconda3\lib\site-packages\openpyxl\styles\fills.py in _from_tree(cls, el)
#     100             desc = localname(child)
#     101             attrib[desc] = Color.from_tree(child)
# --> 102         return cls(**attrib)
#     103
#     104
#
# TypeError: __init__() got an unexpected keyword argument 'extLst'

# %%
download_path = "./xlsxDownloads/1000-10000kb/"
search_xlsx_on_github(1000, 9999, download_path, debug=False)
# Out:
# https://api.github.com/search/code?q=extension:xlsx+size:>1000+size:<9999&per_page=100
# Wed, 15 Dec 2021 08:32:23 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:32:54 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:33:29 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:34:00 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:34:35 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:35:06 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:35:39 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:36:11 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:36:45 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:37:16 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:37:50 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:38:21 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:38:56 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:39:27 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:40:02 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:40:34 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:41:09 GMT: Hit rate limit. Retry after 30 seconds
# Wed, 15 Dec 2021 08:41:40 GMT: Hit rate limit. Retry after 30 seconds

# %%
download_path = "./xlsxDownloads/500-1000kb/"
search_xlsx_on_github(500, 999, download_path, debug=False)
